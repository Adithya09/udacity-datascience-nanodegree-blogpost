# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("survey_results_public.csv")

# %%
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51392 entries, 0 to 51391
# Columns: 154 entries, Respondent to ExpectedSalary
# dtypes: float64(6), int64(1), object(147)
# memory usage: 60.4+ MB

# %%
df.describe()
# Out:
#          Respondent  CareerSatisfaction  JobSatisfaction  HoursPerWeek  \
# count  51392.000000        42695.000000     40376.000000  20600.000000
# mean   25696.500000            7.300574         6.957078      3.952282
# std    14835.736854            1.955444         2.167652      7.564722
# min        1.000000            0.000000         0.000000      0.000000
# 25%    12848.750000            6.000000         6.000000      1.000000
# 50%    25696.500000            8.000000         7.000000      1.000000
# 75%    38544.250000            9.000000         8.000000      4.000000
# max    51392.000000           10.000000        10.000000     40.000000
#
#        StackOverflowSatisfaction         Salary  ExpectedSalary
# count               36592.000000   12891.000000     2566.000000
# mean                    8.429875   56298.480641    33142.220468
# std                     1.390635   39880.905277    30162.988829
# min                     0.000000       0.000000        0.000000
# ...

# %%
df.dtypes.value_counts()
# Out:
# object     147
# float64      6
# int64        1
# Name: count, dtype: int64

# %% [markdown]
# ## Question 1: Remote work and job satisfaction
# #### What are the main indicators of job satisfaction and can we use these relevant indicators to accurately predict job satisfaction for a given employee in the technology field?

# %%
q1_columns = ['HomeRemote', 'JobSatisfaction', 'Professional', 'Salary', 'Country', 'CompanyType', 'CompanySize']
q1_df = df[q1_columns]

# %%
q1_df.head()
# Out:
#                                           HomeRemote  JobSatisfaction  \
# 0                                                NaN              NaN
# 1              More than half, but not all, the time              NaN
# 2  Less than half the time, but at least one day ...              9.0
# 3  Less than half the time, but at least one day ...              3.0
# 4                                              Never              8.0
#
#                                         Professional    Salary  \
# 0                                            Student       NaN
# 1                                            Student       NaN
# 2                             Professional developer  113750.0
# 3  Professional non-developer who sometimes write...       NaN
# 4                             Professional developer       NaN
#
#           Country                                        CompanyType  \
# 0   United States                                                NaN
# ...

# %%
# Check for missing values and data types in the selected columns
print(q1_df.info())
print(q1_df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51392 entries, 0 to 51391
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   HomeRemote       44008 non-null  object
#  1   JobSatisfaction  40376 non-null  float64
#  2   Professional     51392 non-null  object
#  3   Salary           12891 non-null  float64
#  4   Country          51392 non-null  object
#  5   CompanyType      38823 non-null  object
#  6   CompanySize      38922 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 2.7+ MB
# None
# HomeRemote          7384
# JobSatisfaction    11016
# Professional           0
# Salary             38501
# Country                0
# CompanyType        12569
# CompanySize        12470
# dtype: int64

# %% [markdown]
# ### Filtering data to only include entries with salary data

# %%
q1_df_with_salary = q1_df.dropna(subset=['Salary'])

# %%
print(q1_df_with_salary.isnull().sum())
# Out:
# HomeRemote          8
# JobSatisfaction    39
# Professional        0
# Salary              0
# Country             0
# CompanyType        23
# CompanySize        11
# dtype: int64

# %%
# Since less than 5% of the subset is null, let us remove these rows
# Out:
# CompanySize
# 20 to 99 employees          3065
# 100 to 499 employees        2610
# 10,000 or more employees    1823
# 10 to 19 employees          1337
# 1,000 to 4,999 employees    1288
# Fewer than 10 employees     1184
# 500 to 999 employees         851
# 5,000 to 9,999 employees     520
# I don't know                 161
# I prefer not to answer        41
# NaN                           11
# Name: count, dtype: int64

# %%
q1_df_clean = q1_df_with_salary.dropna()

# %%
print(q1_df_clean.isnull().sum())
# Out:
# HomeRemote         0
# JobSatisfaction    0
# Professional       0
# Salary             0
# Country            0
# CompanyType        0
# CompanySize        0
# dtype: int64

# %%
# Checking for outliers in salary
plt.figure(figsize=(10, 6))
sns.boxplot(x=q1_df['Salary'])
plt.title('Boxplot of Salary')
plt.xlabel('Salary')
plt.show()

# %%
q1_df_clean.loc[:, 'JobSatisfactionCategory'] = pd.cut(
    q1_df_clean['JobSatisfaction'],
    bins=[0, 3, 7, 10],
    labels=['0-3', '4-7', '8-10'],
    right=False
)

# %%
# Remote Work Status vs. Job Satisfaction
plt.figure(figsize=(12, 6))
sns.countplot(x='HomeRemote', hue='JobSatisfactionCategory', data=q1_df_clean)
plt.title('Job Satisfaction Categories by Remote Work Status')
plt.xlabel('Remote Work Status')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Job Satisfaction Score')
plt.tight_layout()
plt.show()
